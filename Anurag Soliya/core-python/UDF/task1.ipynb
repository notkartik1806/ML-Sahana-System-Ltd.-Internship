# %%
n = int(input("Enter number of lists: "))
lists = [[] for _ in range(n)]
for i in range(n):
    count1 = int(input(f"enter number of element for list{i}"))
    while count1:
        inp = int(input("enter element: "))
        lists[i].append(inp)
        count1 -= 1


List1 =  [42, 7, 91, 13, 58]
List2 =  [3, 77, 24, 88, 10, 64, 51]

def calc(a):
    print(a)
def calc2(a , b):
    for i in b:
        a.append(i)
    print(a)
    print(max(a))
    print(min(a))

def calc3(a,b,c):
    for i in b:
        a.append(i)
    for i in c:
        a.append(i)
    print(sum(a))

list3 = [42, 7, 91, 13, 15]



calc2(List1 , List2)

calc3(List1, List2, list3)

def calc4(*lists):
    combined = []
    for lst in lists:
        combined += lst

    print(combined)

    squares = map(lambda x: x ** 2, combined)
    print(*squares)
    odd = filter(lambda x: (x%2!=0) , combined)
    print(*odd)

calc4(List1, List2)
# Out:
# [42, 7, 91, 13, 58, 3, 77, 24, 88, 10, 64, 51]
# 1764 49 8281 169 3364 9 5929 576 7744 100 4096 2601
# False True True True False True True False False False False True
