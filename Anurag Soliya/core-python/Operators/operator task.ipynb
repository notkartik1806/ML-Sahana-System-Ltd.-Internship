# %%
my_list = []

count = int(input("enter number of elements: "))

while count != 0:
    my_list.append(int(input("enter element: ")))
    count = count - 1

print(my_list)

total = sum(my_list)
print(total)
# Out:
# [1, 2, 3, 4, 5]
# 15
